# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing necessary libraries
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# Read the datasets
train = pd.read_csv("train2.csv", encoding='latin-1')
test = pd.read_csv("test2.csv", encoding='latin-1')

# making copies of train and test dataset
train_copy = train.copy()
test_copy = test.copy()

# Combine train and test datasets
combined_data = pd.concat([train_copy, test_copy])

# Reset index
combined_data.reset_index(drop=True, inplace=True)

# Display the combined dataset
print(combined_data.head())
# Out:
#          Date       Invoice ID            Product Line              Item_Type  \
# 0  01/27/2019  SI478-BNY-78/79     KAACH CHURA SET 'B'                  Dairy
# 1  02/08/2019  SI479-BNY-78/79         DABUR HONEY 1KG            Soft Drinks
# 2  02/07/2019  SI480-BNY-78/79         KAVERI MEHENDI                    Meat
# 3  02/17/2019  SI480-BNY-78/79               SCAP BEND  Fruits and Vegetables
# 4  03/02/2019  SI480-BNY-78/79  KOOL MANGO FRUTI 200ML              Household
#
#   BASEUNIT  Quantity  Unit price   Tax 5%    cogs     Total   DIVISION
# 0       PC       8.0       58.22  23.2880  465.76  489.0480  Maitidevi
# 1       PC       7.0       86.31  30.2085  604.17  634.3785  Maitidevi
# 2       PC      10.0       43.19  21.5950  431.90  453.4950  Maitidevi
# 3       PC       5.0       34.56   8.6400  172.80  181.4400  Maitidevi
# 4       PC       3.0       88.63  13.2945  265.89  279.1845  Maitidevi

# %%
# Generates summary statistics for numerical columns in the train dataset
combined_data.describe()
# Out:
#           Quantity   Unit price       Tax 5%         cogs        Total
# count  1999.000000  1999.000000  1999.000000  1999.000000  1999.000000
# mean      3.505753    74.561641    59.525775   209.668365   224.047075
# std       3.150519   123.099714   138.374044   232.633399   248.484000
# min       1.000000     4.424779  -296.460177  -296.460177  -335.000000
# 25%       1.000000    30.000000     9.319000    53.097345    60.000000
# 50%       2.000000    54.360000    24.332000   122.123894   135.000000
# 75%       6.000000    88.495575    57.522124   280.980000   300.000000
# max      30.000000  2743.362832  2743.362832  2743.362832  3100.000000

# %%
print(combined_data)
# Out:
#             Date       Invoice ID                Product Line  \
# 0     01/27/2019  SI478-BNY-78/79         KAACH CHURA SET 'B'
# 1     02/08/2019  SI479-BNY-78/79             DABUR HONEY 1KG
# 2     02/07/2019  SI480-BNY-78/79             KAVERI MEHENDI
# 3     02/17/2019  SI480-BNY-78/79                   SCAP BEND
# 4     03/02/2019  SI480-BNY-78/79      KOOL MANGO FRUTI 200ML
# ...          ...              ...                         ...
# 1995  07/26/2021  SI478-BNY-78/79                   SCAP BEND
# 1996  07/26/2021  SI478-BNY-78/79        AZZABKO 21LOVE 100ML
# 1997  07/26/2021  SI478-BNY-78/79       SARA NAIL POLISH 8ML
# 1998  07/26/2021  SI478-BNY-78/79  CELLO SUNFLOWER OIL 500ML
# 1999         NaN              NaN                         NaN
#
#                   Item_Type BASEUNIT  Quantity  Unit price      Tax 5%  \
# 0                     Dairy       PC       8.0   58.220000   23.288000
# 1               Soft Drinks       PC       7.0   86.310000   30.208500
# ...

# %%
# Prints the number of missing values (null values) in each column of the train dataset
print(combined_data.isnull().sum())
# Out:
# Date            1
# Invoice ID      1
# Product Line    1
# Item_Type       1
# BASEUNIT        1
# Quantity        1
# Unit price      1
# Tax 5%          1
# cogs            1
# Total           1
# DIVISION        0
# dtype: int64

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1999 non-null   object
#  1   Invoice ID    1999 non-null   object
#  2   Product Line  1999 non-null   object
#  3   Item_Type     1999 non-null   object
#  4   BASEUNIT      1999 non-null   object
#  5   Quantity      1999 non-null   float64
#  6   Unit price    1999 non-null   float64
#  7   Tax 5%        1999 non-null   float64
#  8   cogs          1999 non-null   float64
#  9   Total         1999 non-null   float64
#  10  DIVISION      2000 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 172.0+ KB

# %%
# Remove rows with missing values from the combined dataset
combined_data_cleaned = combined_data.dropna()

# Display the cleaned dataset
print("Cleaned dataset:")
print(combined_data_cleaned)
# Out:
# Cleaned dataset:
#             Date       Invoice ID                Product Line  \
# 0     01/27/2019  SI478-BNY-78/79         KAACH CHURA SET 'B'
# 1     02/08/2019  SI479-BNY-78/79             DABUR HONEY 1KG
# 2     02/07/2019  SI480-BNY-78/79             KAVERI MEHENDI
# 3     02/17/2019  SI480-BNY-78/79                   SCAP BEND
# 4     03/02/2019  SI480-BNY-78/79      KOOL MANGO FRUTI 200ML
# ...          ...              ...                         ...
# 1994  07/26/2021  SI478-BNY-78/79      OBN NAILPOLISH REMOVER
# 1995  07/26/2021  SI478-BNY-78/79                   SCAP BEND
# 1996  07/26/2021  SI478-BNY-78/79        AZZABKO 21LOVE 100ML
# 1997  07/26/2021  SI478-BNY-78/79       SARA NAIL POLISH 8ML
# 1998  07/26/2021  SI478-BNY-78/79  CELLO SUNFLOWER OIL 500ML
#
#                   Item_Type BASEUNIT  Quantity  Unit price      Tax 5%  \
# 0                     Dairy       PC       8.0   58.220000   23.288000
# ...

# %%
# Prints the number of missing values (null values) in each column of the train dataset
print(combined_data_cleaned.isnull().sum())
# Out:
# Date            0
# Invoice ID      0
# Product Line    0
# Item_Type       0
# BASEUNIT        0
# Quantity        0
# Unit price      0
# Tax 5%          0
# cogs            0
# Total           0
# DIVISION        0
# dtype: int64

# %%
# Checking the shape of the training and testing datasets

print(combined_data_cleaned.shape)
# Out:
# (1999, 11)

# %%
# checking the columns of the train set

print(combined_data_cleaned.columns)
# Out:
# Index(['Date', 'Invoice ID', 'Product Line', 'Item_Type', 'BASEUNIT',
#        'Quantity', 'Unit price', 'Tax 5%', 'cogs', 'Total', 'DIVISION'],
#       dtype='object')

# %%
# Displaying the data types of each column in the 'train' dataset
combined_data_cleaned.dtypes
# Out:
# Date             object
# Invoice ID       object
# Product Line     object
# Item_Type        object
# BASEUNIT         object
# Quantity        float64
# Unit price      float64
# Tax 5%          float64
# cogs            float64
# Total           float64
# DIVISION         object
# dtype: object

# %%
# Counting the occurrences of each unique item in the 'Invoice ID' column of the combined_data_cleaned dataset

combined_data_cleaned['Invoice ID'].value_counts()
# Out:
# Invoice ID
# SI709-BNY-78/79    16
# SI716-BNY-78/79    14
# SI758-BNY-78/79    14
# SI802-BNY-78/79    14
# SI260-BNY-78/79    14
#                    ..
# SI16-BNY-78/79      1
# SI18-BNY-78/79      1
# SI19-BNY-78/79      1
# SI20-BNY-78/79      1
# SI57-BNY-78/79      1
# Name: count, Length: 895, dtype: int64

# %%
# we will analyze only the combined_data_cleaned set

combined_data_cleaned['Invoice ID'].value_counts(normalize = True)
combined_data_cleaned['Invoice ID'].value_counts().plot.hist()
plt.title('"Distribution of Invoice IDs "')
plt.xlabel('Invoice ID')
plt.ylabel('Number of Items')
plt.legend()
plt.show()

# %%
# checking the different items in Item Type

combined_data_cleaned['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    306
# Snack Foods              272
# Household                205
# Frozen Foods             198
# Dairy                    186
# Canned                   154
# Baking Goods             132
# Meat                     120
# Soft Drinks              104
# Health and Hygiene       102
# Breads                    52
# Others                    48
# Hard Drinks               46
# Breakfast                 34
# Starchy Foods             30
# Seafood                   10
# Name: count, dtype: int64

# %%
# we will analyze only the combined_data_cleaned set

combined_data_cleaned['Item_Type'].value_counts(normalize = True)
combined_data_cleaned['Item_Type'].value_counts().plot.bar()
plt.title('Different types of item')
plt.xlabel('Item')
plt.ylabel('Number of Items')
plt.show()

# %%
# Counting the occurrences of each unique value in the 'Product Line' column
# and displaying the counts
combined_data_cleaned['Product Line'].value_counts()
# Out:
# Product Line
# KOOL MANGO FRUTI 200ML              32
# SNOW FUN TOP KULFI                  32
# AAYO ULTRA LAUNDARY  SOAP 180GMS    30
# CELLO SUNFLOWER OIL 500ML           30
# NMC THEKI DAHI 500ML                29
#                                     ..
# BLACK BOX RUBBER                     1
# IHUIDIA BEAUTY MATTE LIPSTICK        1
# PAICHO ORANGE JAM 500GM              1
# TOPS SCHEZWAN SAUCE 340GRM           1
# HAJMOLA 120 TAB CHATCOLA             1
# Name: count, Length: 658, dtype: int64

# %%
# Convert the 'Date' column to datetime with the correct format
combined_data['Date'] = pd.to_datetime(combined_data['Date'], format='%m/%d/%Y')

# Filter the dataset for the specified date range
start_date = '01-27-2019'  # Adjusted format to match MM-DD-YYYY
end_date = '07-26-2021'    # Adjusted format to match MM-DD-YYYY

date_range_data = combined_data[(combined_data['Date'] >= start_date) & (combined_data['Date'] <= end_date)]

# Check if there's any data for the specified date range
if date_range_data.empty:
    print("No data available for the specified date range")
else:
    # Get the value counts of 'Product Line' for the specified date range
    product_counts = date_range_data['Product Line'].value_counts()

    # Get the top 20 selling products
    top_20_products = product_counts.head(20)

    # Plotting
    top_20_products.plot.bar()
    plt.title('Top 20 Selling Products')
    plt.xlabel('Product Line')
    plt.ylabel('Number of Items')
    plt.show()

# %%
# checking the different types of Outlet Identifier

combined_data_cleaned['DIVISION'].value_counts()
# Out:
# DIVISION
# Suryabinayak    644
# panga           476
# Koteshwor       392
# SanoThimi       384
# maitidevi        69
# Maitidevi        28
# Sathi Mart        6
# Name: count, dtype: int64

# %%
# we will analyze only the combined_data_cleaned set
  
combined_data_cleaned['DIVISION'].value_counts(normalize = True)
combined_data_cleaned['DIVISION'].value_counts().plot.bar()
plt.title('Different types of outlet identifier in the store')
plt.xlabel('Item')
plt.ylabel('Number of Items')
plt.show()

# %%
# Checking unique values in the columns of combined_data_cleaned dataset
combined_data_cleaned.apply(lambda x: len(x.unique()))
# Out:
# Date             100
# Invoice ID       895
# Product Line     658
# Item_Type         16
# BASEUNIT           4
# Quantity          13
# Unit price      1156
# Tax 5%          1244
# cogs            1261
# Total           1246
# DIVISION           7
# dtype: int64

# %%
# Preprocessing:
#Select numeric columns for independent variables (x)
numeric_columns = combined_data_cleaned.select_dtypes(include=['int', 'float']).columns
x = combined_data_cleaned[numeric_columns].drop('Total', axis=1)  # Assuming 'Total' is the dependent variable

# Dependent variable (y)
y = combined_data_cleaned['Total']

print(x.shape)
print(y.shape)
# Out:
# (1999, 4)
# (1999,)

# %%
from sklearn.model_selection import train_test_split

# Define your features (X) and target variable (y)
x = combined_data_cleaned.drop(columns=['Total'])  # Assuming 'Total' is the target variable
y = combined_data_cleaned['Total']

# Split the dataset into 70% training and 30% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Print the shapes of the subsets
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1399, 10)
# y_train shape: (1399,)
# x_test shape: (600, 10)
# y_test shape: (600,)

# %%
numeric_columns =combined_data_cleaned.select_dtypes(include=['int', 'float']).columns
print("Numeric Columns:")
print(numeric_columns)
# Out:
# Numeric Columns:
# Index(['Quantity', 'Unit price', 'Tax 5%', 'cogs', 'Total'], dtype='object')

# %%
# Calculate and print a summary of missing values in each column of the DataFrame 'combined_data_cleaned'.
missing_values_summary =combined_data_cleaned.isnull().sum()
print("Missing Values Summary:")
print(missing_values_summary)
# Out:
# Missing Values Summary:
# Date            0
# Invoice ID      0
# Product Line    0
# Item_Type       0
# BASEUNIT        0
# Quantity        0
# Unit price      0
# Tax 5%          0
# cogs            0
# Total           0
# DIVISION        0
# dtype: int64

# %% [markdown]
# # Modelling
#
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Define your features (independent variables) and target variable (dependent variable)
x = combined_data_cleaned.drop(columns=['Total'])  # Assuming 'Total' is the target variable
y = combined_data_cleaned['Total']

# Split the dataset into 70% training and 30% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(x_train, y_train)

# Predict the target variable for the test data
y_pred = model.predict(x_test)

# Calculate and print the Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('RMSE:', rmse)

# Calculate and print the R-squared value
r_squared = r2_score(y_test, y_pred)
print('R-squared:', r_squared)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18168\312920967.py in ?()
#      11 # Initialize the linear regression model
#      12 model = LinearRegression()
#      13
#      14 # Fit the model to the training data
# ---> 15 model.fit(x_train, y_train)
#      16
#      17 # Predict the target variable for the test data
#      18 y_pred = model.predict(x_test)
#
# E:\anaconda\anoconda\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# E:\anaconda\anoconda\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
# ...

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 100 , n_jobs = -1)
model.fit(x_train, y_train)

# predicting the  test set results
y_pred = model.predict(x_test)
print(y_pred)

# finding the mean squared error and variance
mse = mean_squared_error(y_test, y_pred)
print("RMSE :",np.sqrt(mse))
print('Variance score: %.2f' % r2_score(y_test, y_pred))

print("Result :",model.score(x_train, y_train))
